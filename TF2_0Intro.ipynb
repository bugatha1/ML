# %% [markdown]
# <a href="https://colab.research.google.com/github/bugatha1/ML/blob/master/TF2_0Intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is my **`title`**

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,10*np.pi,1000)
y = np.sin(x)

# %%
plt.plot(y,x)
